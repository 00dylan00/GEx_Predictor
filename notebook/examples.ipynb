# %%
import sys
import os
import importlib
import numpy as np

sys.path.append(os.path.abspath(".."))

import gex_predictor.GEx_Predictor

importlib.reload(sys.modules['gex_predictor.GEx_Predictor'])
importlib.reload(sys.modules['gex_predictor'])

from gex_predictor import GEx_Predictor

# %%
smiles_kaggle_loaded = np.load("smiles_kaggle_testing.npy", allow_pickle=True)

# Example smiles to predict
smiles_kaggle_loaded
# Out:
# array(['CN(C)C/C=C/C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2cc1O[C@H]1CCOC1',
#        'Cc1ccc(NC(=O)c2ccc(CN3CC[C@H](N(C)C)C3)c(C(F)(F)F)c2)cc1Nc1nccc(-c2cncnc2)n1',
#        'COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1NC(=O)/C=C/CN1CCCCC1.O',
#        'C#Cc1cccc(Nc2ncnc3cc4c(cc23)OCCOCCOCCO4)c1',
#        'O=C(c1ccc(/C=C/c2n[nH]c3ccccc23)cc1)N1CCNCC1',
#        'COCCNCc1ccc(-c2cc3nccc(Oc4ccc(NC(=S)NC(=O)Cc5ccc(F)cc5)cc4F)c3s2)nc1',
#        'CCOc1cc2ncc(C#N)c(Nc3ccc(OCc4ccccn4)c(Cl)c3)c2cc1NC(=O)/C=C/CN(C)C',
#        'CCN(CC)CCNC(=O)c1c(C)[nH]c(/C=C2\\C(=O)Nc3ccc(F)cc32)c1C',
#        'O=C(/C=C/c1cccc(S(=O)(=O)Nc2ccccc2)c1)NO',
#        'COc1cc2c(cc1OC(C)C)[C@H](c1ccc(Cl)cc1)N(c1ccc(N(C)C[C@H]3CC[C@H](N4CCN(C)C(=O)C4)CC3)cc1)C(=O)C2',
#        'O=C(/C=C/c1cccnc1)NCCCCC1CCN(C(=O)c2ccccc2)CC1',
#        'Cn1c2ccccc2c2c3c(c4c5ccccc5n(CCC#N)c4c21)CNC3=O',
#        'COc1ccc(S(=O)(=O)N(C(C)=O)c2ccccc2/C=C/c2cc[n+]([O-])cc2)cc1',
#        'Nc1ncnc2c1c(I)cn2[C@@H]1O[C@H](CO)[C@@H](O)[C@H]1O',
#        'C/C(=C\\c1csc(C)n1)[C@@H]1C[C@@H]2O[C@]2(C)CCC[C@H](C)[C@H](O)[C@@H](C)C(=O)C(C)(C)[C@@H](O)CC(=O)N1',
#        'FC(F)(F)c1ccc(/C=C/c2nc(COc3ccc(CCCCn4ccnn4)cc3)co2)cc1',
#        'COC[C@H](NC(=O)c1cnc(C)s1)C(=O)N[C@@H](COC)C(=O)N[C@@H](Cc1ccccc1)C(=O)[C@@]1(C)CO1',
#        'O=C(O)C[C@H](O)C[C@H](O)/C=C/c1c(C2CC2)nc2ccccc2c1-c1ccc(F)cc1',
#        'C[C@]12C=CC(=O)C=C1CC[C@@H]1[C@@H]2[C@@H](O)C[C@@]2(C)[C@H]1CC[C@]2(O)C(=O)CO',
#        'C[C@@H]1O[C@@H](O[C@@H]2C=C3CC[C@@H]4[C@H](CC[C@]5(C)[C@@H](c6ccc(=O)oc6)CC[C@]45O)[C@@]3(C)CC2)[C@H](O)[C@H](O)[C@H]1O',
#        'CCOc1cc(C(C)(C)C)ccc1C1=N[C@@](C)(c2ccc(Cl)cc2)[C@@](C)(c2ccc(Cl)cc2)N1C(=O)N1CCN(CCCS(C)(=O)=O)CC1',
#        'CN1CCN(c2ccc(Nc3cc(-c4cccc(-n5ccc6cc(C7CC7)cc(F)c6c5=O)c4CO)cn(C)c3=O)nc2)CC1',
#        'CN(C)Cc1ccc(S(=O)(=O)n2ccc(/C=C/C(=O)NO)c2)cc1',
#        'CC1=NN(c2ccc(C(=O)O)cc2)C(=O)/C1=C/c1ccc(-c2cc(C)c(C)cc2[N+](=O)[O-])o1',
#        'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)CC[C@@H](O)C(C)C)CC[C@@H]23)C[C@@H](O)C[C@@H]1O'],
#       dtype=object)

# %%
# Using the best fold to predict:
gex_predictor_best_fold = GEx_Predictor(all_folds=False)
# Out:
# [INFO] Using device: cpu
# [INFO] Loading fold 4 from C:\Users\vadri\OneDrive\Documentos\GEx_Predictor\model\fold_4.pt ...
# [INFO] 1 model(s) loaded (best fold only).

# %%
predictions = gex_predictor_best_fold.predict(smiles_kaggle_loaded)
# Out:
# [INFO] Starting prediction — input_type=SMILES
# ensemble=best fold
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Fragment: COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1NC(=O)/C=C/CN1CCCCC1
# [18:08:50] New largest fragment: COc1cc2ncnc(Nc3ccc(F)c(Cl)c3)c2cc1NC(=O)/C=C/CN1CCCCC1 (58)
# [18:08:50] Fragment: O
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# WARNING:tensorflow:From c:\Users\vadri\AppData\Roaming\pypoetry\venv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# [18:08:50] Initializing MetalDisconnector
# [18:08:50] Running MetalDisconnector
# [18:08:50] Initializing Normalizer
# [18:08:50] Running Normalizer
# [18:08:50] Running LargestFragmentChooser
# [18:08:50] Running Uncharger
# WARNING:tensorflow:From c:\Users\vadri\AppData\Roaming\pypoetry\venv\lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\vadri\AppData\Roaming\pypoetry\venv\lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\vadri\AppData\Roaming\pypoetry\venv\lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\vadri\AppData\Roaming\pypoetry\venv\lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
#
# Parsing SMILES: 25it [00:00, 1499.59it/s]
# Generating signatures:   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 777ms/step
# Generating signatures: 100%|██████████| 1/1 [00:02<00:00,  2.20s/it]
# [STEP] Converting signatures to tensor and performing prediction...
# [INFO] Prediction completed successfully.

# %%
predictions
# Out:
# array([[ 2.2639048 ,  0.5219342 ,  1.0985854 , ..., -0.52265155,
#          0.845027  , -0.19061849],
#        [ 1.37856   ,  0.2921011 ,  0.7082047 , ..., -0.4339677 ,
#          0.19156353, -0.5122457 ],
#        [ 2.2805908 ,  0.4950288 ,  1.0020745 , ..., -0.47705406,
#          0.734041  , -0.18701161],
#        ...,
#        [ 0.360361  ,  1.7107552 ,  0.8923985 , ..., -0.61906517,
#          0.6878781 ,  0.17534932],
#        [ 0.10086828,  0.30263925,  0.55995774, ..., -0.31881884,
#          0.6775801 ,  0.10280202],
#        [ 0.47007024, -0.25269955,  0.35778177, ..., -0.18917042,
#         -0.06350007, -0.5253787 ]], dtype=float32)

# %%
predictions.shape
# Out:
# (25, 1035)

# %%
# Using all the folds to predict:
gex_predictor_all_folds = GEx_Predictor(all_folds=True)
# Out:
# [INFO] Using device: cpu
# [INFO] Loading fold 1 from C:\Users\vadri\OneDrive\Documentos\GEx_Predictor\model\fold_1.pt ...
# [INFO] Loading fold 2 from C:\Users\vadri\OneDrive\Documentos\GEx_Predictor\model\fold_2.pt ...
# [INFO] Loading fold 3 from C:\Users\vadri\OneDrive\Documentos\GEx_Predictor\model\fold_3.pt ...
# [INFO] Loading fold 4 from C:\Users\vadri\OneDrive\Documentos\GEx_Predictor\model\fold_4.pt ...
# [INFO] Loading fold 5 from C:\Users\vadri\OneDrive\Documentos\GEx_Predictor\model\fold_5.pt ...
# [INFO] 5 model(s) loaded (all 5 folds).

# %%
predictions2 = gex_predictor_all_folds.predict(smiles_kaggle_loaded)
# Out:
# [INFO] Starting prediction — input_type=SMILES
# ensemble=5 folds
# Parsing SMILES: 25it [00:00, 2124.30it/s]
# Generating signatures:   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 946ms/step
# Generating signatures: 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
# [STEP] Converting signatures to tensor and performing prediction...
# [INFO] Prediction completed successfully.

# %%
predictions2
# Out:
# array([[ 2.2654614 ,  0.50859493,  1.1507574 , ..., -0.52070796,
#          0.8655343 , -0.17996468],
#        [ 1.4265026 ,  0.35619965,  0.61947536, ..., -0.44545183,
#          0.20149454, -0.43258804],
#        [ 2.3159952 ,  0.4967982 ,  1.0242146 , ..., -0.4797    ,
#          0.74782103, -0.19618738],
#        ...,
#        [ 0.4489432 ,  1.7453003 ,  0.822865  , ..., -0.6157415 ,
#          0.7408401 ,  0.20535672],
#        [ 0.14932491,  0.18792823,  0.56642294, ..., -0.30796385,
#          0.68441963,  0.08223657],
#        [ 0.49295244, -0.2899913 ,  0.358697  , ..., -0.19367322,
#         -0.07503041, -0.5003568 ]], dtype=float32)

# %%
# Diferencia absoluta media
mae = np.mean(np.abs(predictions - predictions2))
mse = np.mean((predictions - predictions2) ** 2)

print(f"MAE:  {mae:.4f}")
print(f"MSE:  {mse:.4f}")
# Out:
# MAE:  0.0691
# MSE:  0.0120
